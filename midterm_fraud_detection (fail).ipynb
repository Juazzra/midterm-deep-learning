# %%
# 1. IMPORT LIBRARY
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2. LOAD DATA (SURVIVAL MODE)
# Kita batasi 50.000 baris karena kenadala waktu dan memori
filename = "train_transaction.csv"
try:
    print("Sedang membaca data... (Membaca 50.000 baris pertama)")
    df = pd.read_csv(filename, nrows=50000)
    print(f"Data berhasil dimuat! Ukuran: {df.shape}")
except FileNotFoundError:
    print("ERROR: File train_transaction.csv tidak ditemukan!")
# Out:
# Sedang membaca data... (Membaca 50.000 baris pertama)
# ERROR: File train_transaction.csv tidak ditemukan!

# %%
# 3. PREPROCESSING CEPAT
# Pisahkan Target
target = 'isFraud'
y = df[target]
X = df.drop([target, 'TransactionID'], axis=1) # Hapus ID dan Target

# Hanya ambil kolom NUMERIK (Cara cepat hindari error text processing)
X = X.select_dtypes(include=[np.number])
print(f"Menggunakan {X.shape[1]} fitur numerik.")

# Isi data kosong (NaN) dengan angka -1 (Praktek umum di pohon keputusan/DL)
X = X.fillna(-1)

# Scaling (Wajib untuk Neural Network agar loss turun stabil)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split Data (80% Latih, 20% Uji)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# Cek Ketimpangan Data (Fraud biasanya sedikit)
print("\nJumlah Fraud di Training set:")
print(y_train.value_counts())

#gagal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 # 3. PREPROCESSING CEPAT
#       2 # Pisahkan Target
#       3 target = 'isFraud'
# ----> 4 y = df[target]
#       5 X = df.drop([target, 'TransactionID'], axis=1) # Hapus ID dan Target
#       7 # Hanya ambil kolom NUMERIK (Cara cepat hindari error text processing)
#
# NameError: name 'df' is not defined
